# %%
import numpy as np
import matplotlib.pyplot as plt
height = np.random.normal(140,20,1000)
plt.figure(dpi=200)
plt.title("Height distribution")
plt.xlabel("Height (cm) ")
plt.ylabel("Frequency")
plt.hist(height, bins=30,ec="gold")
# Out:
# (array([  1.,   0.,   0.,   1.,   1.,   1.,   6.,   6.,   8.,  18.,  22.,
#          39.,  59.,  70.,  78., 104., 105.,  94., 100.,  93.,  61.,  47.,
#          30.,  23.,  15.,  11.,   3.,   1.,   1.,   2.]),
#  array([ 50.99439088,  56.2421747 ,  61.48995851,  66.73774233,
#          71.98552615,  77.23330997,  82.48109378,  87.7288776 ,
#          92.97666142,  98.22444523, 103.47222905, 108.72001287,
#         113.96779669, 119.2155805 , 124.46336432, 129.71114814,
#         134.95893195, 140.20671577, 145.45449959, 150.70228341,
#         155.95006722, 161.19785104, 166.44563486, 171.69341867,
#         176.94120249, 182.18898631, 187.43677013, 192.68455394,
#         197.93233776, 203.18012158, 208.42790539]),
#  <BarContainer object of 30 artists>)
